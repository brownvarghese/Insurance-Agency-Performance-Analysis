# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
import pandas as pd
import missingno as msno
import numpy as np
sns.set(style="white")
matplotlib.rc('figure', figsize=[12, 5])

# %%
Ins_df = pd.read_csv("finalapi.csv")
Ins_df.head()
# Out:
#    AGENCY_ID  PRIMARY_AGENCY_ID   PROD_ABBR PROD_LINE STATE_ABBR  \
# 0          3                  3  BOILERMACH        CL         IN
# 1          3                  3  BOILERMACH        CL         IN
# 2          3                  3  BOILERMACH        CL         IN
# 3          3                  3  BOILERMACH        CL         IN
# 4          3                  3  BOILERMACH        CL         IN
#
#    STAT_PROFILE_DATE_YEAR  RETENTION_POLY_QTY  POLY_INFORCE_QTY  \
# 0                    2005                   0                 0
# 1                    2006                   0                 0
# 2                    2007                   0                 0
# 3                    2008                   0                 0
# 4                    2009                   0                 0
#
#    PREV_POLY_INFORCE_QTY  NB_WRTN_PREM_AMT  ...  PL_BOUND_CT_ELINKS  \
# 0                      0              40.0  ...                   0
# ...

# %%
# We only work on 23 Columns so a data field on those columns

Updated_Ins_df = Ins_df[["AGENCY_ID","PRIMARY_AGENCY_ID","PROD_ABBR","PROD_LINE","STATE_ABBR",
                         "STAT_PROFILE_DATE_YEAR","NB_WRTN_PREM_AMT","WRTN_PREM_AMT",                         
                         "LOSS_RATIO_3YR","GROWTH_RATE_3YR","ACTIVE_PRODUCERS","MAX_AGE","MIN_AGE","VENDOR_IND"]]

Updated_Ins_df.head()

#Updated_Ins_df.to_csv('output.csv', index=False)
# Out:
#    AGENCY_ID  PRIMARY_AGENCY_ID   PROD_ABBR PROD_LINE STATE_ABBR  \
# 0          3                  3  BOILERMACH        CL         IN
# 1          3                  3  BOILERMACH        CL         IN
# 2          3                  3  BOILERMACH        CL         IN
# 3          3                  3  BOILERMACH        CL         IN
# 4          3                  3  BOILERMACH        CL         IN
#
#    STAT_PROFILE_DATE_YEAR  NB_WRTN_PREM_AMT  WRTN_PREM_AMT  LOSS_RATIO_3YR  \
# 0                    2005              40.0        3074.63    99999.000000
# 1                    2006             151.0        6562.28        0.695390
# 2                    2007              40.0        6205.11        0.472729
# 3                    2008              69.0        5159.89        0.445760
# 4                    2009              28.0        4527.71        0.337674
#
#    GROWTH_RATE_3YR  ACTIVE_PRODUCERS  MAX_AGE  MIN_AGE VENDOR_IND
# ...

# %%
# Locate value 9999 in Agency_ID

Updated_Ins_df.loc[Updated_Ins_df['AGENCY_ID'] == 99999]

# Looks like we ar good with Agency_ID
# Out:
# Empty DataFrame
# Columns: [AGENCY_ID, PRIMARY_AGENCY_ID, PROD_ABBR, PROD_LINE, STATE_ABBR, STAT_PROFILE_DATE_YEAR, NB_WRTN_PREM_AMT, WRTN_PREM_AMT, LOSS_RATIO_3YR, GROWTH_RATE_3YR, ACTIVE_PRODUCERS, MAX_AGE, MIN_AGE, VENDOR_IND]
# Index: []

# %%
# Locate value 99999 in PRIMARY_AGENCY_ID

Updated_Ins_df.loc[Updated_Ins_df['PRIMARY_AGENCY_ID'] == 99999].head()

# THere are 37874  rows with value 99999 and we will keep these
# Out:
#      AGENCY_ID  PRIMARY_AGENCY_ID   PROD_ABBR PROD_LINE STATE_ABBR  \
# 511         11              99999  BOILERMACH        CL         IN
# 512         11              99999  BOILERMACH        CL         IN
# 513         11              99999  BOILERMACH        CL         IN
# 514         11              99999  BOILERMACH        CL         IN
# 515         11              99999  BOILERMACH        CL         IN
#
#      STAT_PROFILE_DATE_YEAR  NB_WRTN_PREM_AMT  WRTN_PREM_AMT  LOSS_RATIO_3YR  \
# 511                    2005               0.0         242.00    99999.000000
# 512                    2006               0.0         406.00        0.603349
# 513                    2007               0.0         406.00        0.285437
# 514                    2008               0.0         164.00        0.182169
# 515                    2009               0.0          70.31       -0.018948
#
#      GROWTH_RATE_3YR  ACTIVE_PRODUCERS  MAX_AGE  MIN_AGE VENDOR_IND
# ...

# %%
# creat a new df where  PRIMARY_AGENCY_ID =99999 exists

new_df = Updated_Ins_df

# %%
# Locate value 99999 in PROD_ABBR

new_df.loc[new_df['PROD_ABBR'] == 99999]

# THere are no values so we should be good.
# Out:
# Empty DataFrame
# Columns: [AGENCY_ID, PRIMARY_AGENCY_ID, PROD_ABBR, PROD_LINE, STATE_ABBR, STAT_PROFILE_DATE_YEAR, NB_WRTN_PREM_AMT, WRTN_PREM_AMT, LOSS_RATIO_3YR, GROWTH_RATE_3YR, ACTIVE_PRODUCERS, MAX_AGE, MIN_AGE, VENDOR_IND]
# Index: []

# %%
# Locate value 99999 in PROD_LINE

new_df.loc[new_df['PROD_LINE'] == 99999]

# THere are no values of 99999 so we should be good.
# Out:
# Empty DataFrame
# Columns: [AGENCY_ID, PRIMARY_AGENCY_ID, PROD_ABBR, PROD_LINE, STATE_ABBR, STAT_PROFILE_DATE_YEAR, NB_WRTN_PREM_AMT, WRTN_PREM_AMT, LOSS_RATIO_3YR, GROWTH_RATE_3YR, ACTIVE_PRODUCERS, MAX_AGE, MIN_AGE, VENDOR_IND]
# Index: []

# %%
# Locate value 99999 in STATE_ABBR

new_df.loc[new_df['STATE_ABBR'] == 99999]

# THere are no values of 99999 so we should be good.
# Out:
# Empty DataFrame
# Columns: [AGENCY_ID, PRIMARY_AGENCY_ID, PROD_ABBR, PROD_LINE, STATE_ABBR, STAT_PROFILE_DATE_YEAR, NB_WRTN_PREM_AMT, WRTN_PREM_AMT, LOSS_RATIO_3YR, GROWTH_RATE_3YR, ACTIVE_PRODUCERS, MAX_AGE, MIN_AGE, VENDOR_IND]
# Index: []

# %%
# Locate value 99999 in STAT_PROFILE_DATE_YEAR

new_df.loc[new_df['STAT_PROFILE_DATE_YEAR'] == 99999]

# THere are no values of 99999 so we should be good.
# Out:
# Empty DataFrame
# Columns: [AGENCY_ID, PRIMARY_AGENCY_ID, PROD_ABBR, PROD_LINE, STATE_ABBR, STAT_PROFILE_DATE_YEAR, NB_WRTN_PREM_AMT, WRTN_PREM_AMT, LOSS_RATIO_3YR, GROWTH_RATE_3YR, ACTIVE_PRODUCERS, MAX_AGE, MIN_AGE, VENDOR_IND]
# Index: []

# %%
# Locate value 99999 in NB_WRTN_PREM_AMT

new_df.loc[new_df['NB_WRTN_PREM_AMT'] == 99999]

# THere is only 1 value with 99999
# Out:
#         AGENCY_ID  PRIMARY_AGENCY_ID   PROD_ABBR PROD_LINE STATE_ABBR  \
# 209024       9733               9733  FIREALLIED        CL         OH
#
#         STAT_PROFILE_DATE_YEAR  NB_WRTN_PREM_AMT  WRTN_PREM_AMT  \
# 209024                    2014           99999.0      267009.56
#
#         LOSS_RATIO_3YR  GROWTH_RATE_3YR  ACTIVE_PRODUCERS  MAX_AGE  MIN_AGE  \
# 209024         0.70552         0.005181                55       87       35
#
#        VENDOR_IND
# 209024          Y

# %%
# Locate value 99999 in NB_WRTN_PREM_AMT

new_df.loc[new_df['WRTN_PREM_AMT'] == 99999].head()

# THere is no value with 99999
# Out:
# Empty DataFrame
# Columns: [AGENCY_ID, PRIMARY_AGENCY_ID, PROD_ABBR, PROD_LINE, STATE_ABBR, STAT_PROFILE_DATE_YEAR, NB_WRTN_PREM_AMT, WRTN_PREM_AMT, LOSS_RATIO_3YR, GROWTH_RATE_3YR, ACTIVE_PRODUCERS, MAX_AGE, MIN_AGE, VENDOR_IND]
# Index: []

# %%
# Locate value 99999 in PREV_WRTN_PREM_AMT

new_df.loc[new_df['LOSS_RATIO_3YR'] == 99999].head()

# THere is 12000 rows value with 99999
# Out:
#     AGENCY_ID  PRIMARY_AGENCY_ID   PROD_ABBR PROD_LINE STATE_ABBR  \
# 0           3                  3  BOILERMACH        CL         IN
# 10          3                  3  BOILERMACH        CL         IN
# 11          3                  3  BOILERMACH        CL         KY
# 21          3                  3  BOILERMACH        CL         KY
# 22          3                  3         BOP        CL         IN
#
#     STAT_PROFILE_DATE_YEAR  NB_WRTN_PREM_AMT  WRTN_PREM_AMT  LOSS_RATIO_3YR  \
# 0                     2005              40.0        3074.63         99999.0
# 10                    2015               0.0        1922.83         99999.0
# 11                    2005               0.0         361.68         99999.0
# 21                    2015               0.0           0.00         99999.0
# 22                    2005               0.0       13607.47         99999.0
#
#     GROWTH_RATE_3YR  ACTIVE_PRODUCERS  MAX_AGE  MIN_AGE VENDOR_IND
# ...

# %%
# Find out the median value of LOSS_RATIO_3YR 
new_df.LOSS_RATIO_3YR.median()
# Out:
# 0.543219269

# %%
# replace the value 99999 with the median value for simplify

new_df.loc[:, 'LOSS_RATIO_3YR'].replace([99999], [new_df.LOSS_RATIO_3YR.median()], inplace=True)
new_df.head()
# Out:
# /Users/rmahalin/anaconda3/envs/Pythondata/lib/python3.7/site-packages/pandas/core/generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#    AGENCY_ID  PRIMARY_AGENCY_ID   PROD_ABBR PROD_LINE STATE_ABBR  \
# 0          3                  3  BOILERMACH        CL         IN
# 1          3                  3  BOILERMACH        CL         IN
# 2          3                  3  BOILERMACH        CL         IN
# 3          3                  3  BOILERMACH        CL         IN
# 4          3                  3  BOILERMACH        CL         IN
#
#    STAT_PROFILE_DATE_YEAR  NB_WRTN_PREM_AMT  WRTN_PREM_AMT  LOSS_RATIO_3YR  \
# 0                    2005              40.0        3074.63        0.543219
# 1                    2006             151.0        6562.28        0.695390
# ...

# %%
# Drop ACTIVE_PRODUCERS , MAX_AGE & MIN_AGE is 99999

new_df.drop(new_df.loc[new_df['ACTIVE_PRODUCERS']==99999].index, inplace=True)
new_df.drop(new_df.loc[new_df['MAX_AGE']==99999].index, inplace=True)
new_df.drop(new_df.loc[new_df['MIN_AGE']==99999].index, inplace=True)

new_df.head()
# Out:
# /Users/rmahalin/anaconda3/envs/Pythondata/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#    AGENCY_ID  PRIMARY_AGENCY_ID   PROD_ABBR PROD_LINE STATE_ABBR  \
# 0          3                  3  BOILERMACH        CL         IN
# 1          3                  3  BOILERMACH        CL         IN
# 2          3                  3  BOILERMACH        CL         IN
# 3          3                  3  BOILERMACH        CL         IN
# 4          3                  3  BOILERMACH        CL         IN
#
#    STAT_PROFILE_DATE_YEAR  NB_WRTN_PREM_AMT  WRTN_PREM_AMT  LOSS_RATIO_3YR  \
# 0                    2005              40.0        3074.63        0.543219
# 1                    2006             151.0        6562.28        0.695390
# ...

# %%
new_df['AVG_AGE'] = (new_df["MAX_AGE"] - new_df["MIN_AGE"]) / new_df["ACTIVE_PRODUCERS"]

new_df['AGENCY_PERFORMANCE'] = new_df["WRTN_PREM_AMT"]*(1-new_df["LOSS_RATIO_3YR"])

new_df["DEMOGRAPHY"] = ""

new_df["INSURABLE_POPULATION"] = ""
new_df.head()
# Out:
# /Users/rmahalin/anaconda3/envs/Pythondata/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/rmahalin/anaconda3/envs/Pythondata/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
new1_df=new_df.sort_values(['STATE_ABBR', 'STAT_PROFILE_DATE_YEAR'], ascending=[True, True])
new1_df=new1_df.rename(columns = {'STATE_ABBR':'State'})
new1_df=new1_df.rename(columns = {'STAT_PROFILE_DATE_YEAR':'Year'})
new1_df.head()
# Out:
#      AGENCY_ID  PRIMARY_AGENCY_ID   PROD_ABBR PROD_LINE State  Year  \
# 0            3                  3  BOILERMACH        CL    IN  2005
# 22           3                  3         BOP        CL    IN  2005
# 44           3                  3    COMMAUTO        CL    IN  2005
# 99           3                  3  COMMINLMAR        CL    IN  2005
# 121          3                  3     COMMPOL        CL    IN  2005
#
#      NB_WRTN_PREM_AMT  WRTN_PREM_AMT  LOSS_RATIO_3YR  GROWTH_RATE_3YR  \
# 0                40.0        3074.63        0.543219          99999.0
# 22                0.0       13607.47        0.543219          99999.0
# 44               49.0      101913.67        0.543219          99999.0
# 99              111.0        6850.32        0.543219          99999.0
# 121               0.0           0.00        0.543219          99999.0
#
#      ACTIVE_PRODUCERS  MAX_AGE  MIN_AGE VENDOR_IND   AVG_AGE  \
# 0                  14       85       48          N  2.642857
# ...

# %%
census_df = pd.read_csv("census_ext.csv")
census_df.head()
# Out:
#   State  Year  INSURABLE_POPULATION
# 0    AK  2005                461168
# 1    AK  2006                469434
# 2    AK  2007                475655
# 3    AK  2008                483416
# 4    AK  2009                491537

# %%
final_agency_df = pd.merge(census_df, new1_df, how='left', on=['State', 'Year'])
final_agency_df
# Out:
#   State  Year  INSURABLE_POPULATION_x  AGENCY_ID  PRIMARY_AGENCY_ID PROD_ABBR  \
# 0    AK  2005                  461168        NaN                NaN       NaN
# 1    AK  2006                  469434        NaN                NaN       NaN
# 2    AK  2007                  475655        NaN                NaN       NaN
# 3    AK  2008                  483416        NaN                NaN       NaN
# 4    AK  2009                  491537        NaN                NaN       NaN
#
#   PROD_LINE  NB_WRTN_PREM_AMT  WRTN_PREM_AMT  LOSS_RATIO_3YR  GROWTH_RATE_3YR  \
# 0       NaN               NaN            NaN             NaN              NaN
# 1       NaN               NaN            NaN             NaN              NaN
# 2       NaN               NaN            NaN             NaN              NaN
# 3       NaN               NaN            NaN             NaN              NaN
# 4       NaN               NaN            NaN             NaN              NaN
#
# ...

# %%
final_agency_df
# Out:
#        State  Year  INSURABLE_POPULATION_x  AGENCY_ID  PRIMARY_AGENCY_ID  \
# 0         AK  2005                  461168        NaN                NaN
# 1         AK  2006                  469434        NaN                NaN
# 2         AK  2007                  475655        NaN                NaN
# 3         AK  2008                  483416        NaN                NaN
# 4         AK  2009                  491537        NaN                NaN
# 5         AK  2010                  505601        NaN                NaN
# 6         AK  2011                  513904        NaN                NaN
# 7         AK  2012                  523490        NaN                NaN
# 8         AK  2013                  530194        NaN                NaN
# 9         AK  2014                  531924        NaN                NaN
# 10        AK  2015                  534628        NaN                NaN
# 11        AL  2005                 3318359        NaN                NaN
# ...

# %%
final_agency_df.to_csv("final_agency_data.csv", header=True)
